# %%
# !pip install mysql-connector-python
# Out:
# Requirement already satisfied: mysql-connector-python in c:\users\mikel\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (9.5.0)
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: C:\Users\MIKEL\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import mysql.connector as connector
import json
with open('info.json') as f:
    info = json.load(f)

connection = connector.connect(
    user=info['user'],
    password=info['password']
)

cursor = connection.cursor()

# %%
show_dbs_query = "SHOW databases;" 
cursor.execute(show_dbs_query)
databases = cursor.fetchall()
for db in databases:
    print(db)
# Out:
# ('information_schema',)
# ('littlelemondb',)
# ('mysql',)
# ('performance_schema',)
# ('sys',)
# ('world',)

# %%
cursor.execute("USE littlelemondb;")
show_tables_query = "SHOW tables"
cursor.execute(show_tables_query)
tables = cursor.fetchall()
for table in tables:
    print(table)
# Out:
# ('bookings',)
# ('customers',)
# ('menu',)
# ('menuitems',)
# ('orderdetails',)
# ('orderds',)
# ('orders',)
# ('ordersview',)
# ('staff',)

# %%
query = """
SELECT 
    customers.Name,
    customers.email,
    customers.Phone,
    orders.TotalCost
FROM customers
INNER JOIN orders
    ON customers.idCustomers = orders.CustomerID
WHERE orders.TotalCost > 60;
"""
cursor.execute(query)
results = cursor.fetchall()
for result in results:
    print(result)
# Out:
# ('Josu Bonilla', 'jb@gmail.com', 698745123, Decimal('80'))
